# %%
# if you want to replace some of data cell then you can do it like below

import pandas as pd

def cell_budget(cell):
    if cell == "Not Available":
        return "Amin"
    return cell

def cell_revenue(cell):
    if cell == "Not Available":
        return "Captain"
    return cell

movies = pd.read_excel("C:\\Users\\HP\\Pandas Practice\\Moives DB\\movies_db_excel_Basics.xlsx", "movies", converters={
    'budget': cell_budget,
    'revenue': cell_revenue
})
print(movies)
# Out:
#     movie_id                                        title   industry
# 0        101                             K.G.F: Chapter 2  Bollywood  \
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                         Thor: The Dark World  Hollywood
# 3        104                               Thor: Ragnarok  Hollywood
# 4        105                       Thor: Love and Thunder  Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                              Bajirao Mastani  Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
# if you wanted to convert the altered data into excel files then you can doit as follows:
# movies.to_excel("C:\\Users\\HP\\Pandas Practice\\Moives DB\\new_altered.xlsx", sheet_name = 'replaced_data')

# %%
import pandas as pd
new_altered = pd.read_excel("C:\\Users\\HP\\Pandas Practice\\Moives DB\\new_altered.xlsx")
new_altered.head(3)
# Out:
#    Unnamed: 0  movie_id                                        title
# 0           0       101                             K.G.F: Chapter 2  \
# 1           1       102  Doctor Strange in the Multiverse of Madness
# 2           2       103                         Thor: The Dark World
#
#     industry  release_year  imdb_rating          studio  language_id budget
# 0  Bollywood          2022          8.4   Hombale Films            3      1  \
# 1  Hollywood          2022          7.0  Marvel Studios            5    200
# 2  Hollywood          2013          6.8  Marvel Studios            5    165
#
#   revenue      unit currency
# 0    12.5  Billions      INR
# 1   954.8  Millions      USD
# 2   644.8  Millions      USD

# %%
import pandas as pd
new_altered1 = pd.read_excel("C:\\Users\\HP\\Pandas Practice\\Moives DB\\new_altered1.xlsx")
new_altered1.head(3)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0         NaN         NaN         NaN         NaN        NaN        NaN  \
# 1         NaN         NaN         NaN         NaN        NaN        NaN
# 2         NaN         NaN         NaN         NaN   movie_id      title
#
#   Unnamed: 6    Unnamed: 7   Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0        NaN           NaN          NaN        NaN          NaN         NaN  \
# 1        NaN           NaN          NaN        NaN          NaN         NaN
# 2   industry  release_year  imdb_rating     studio  language_id      budget
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2     revenue        unit    currency

# %%
with pd.ExcelWriter("C:\\Users\\HP\\Pandas Practice\\Moives DB\\New Microsoft Excel Worksheet.xlsx") as writer:
    movies_financials.to_excel(write, sheet_name="financials")
    movies_financials.to_excel(write, sheet_name="financials")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 with pd.ExcelWriter("C:\\Users\\HP\\Pandas Practice\\Moives DB\\New Microsoft Excel Worksheet.xlsx") as writer:
# ----> 2     movies_financials.to_excel(write, sheet_name="financials")
#       3     movies_financials.to_excel(write, sheet_name="financials")
#
# NameError: name 'movies_financials' is not defined
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 with pd.ExcelWriter("C:\\Users\\HP\\Pandas Practice\\Moives DB\\New Microsoft Excel Worksheet.xlsx") as writer:
#       2     movies_financials.to_excel(write, sheet_name="financials")
#       3     movies_financials.to_excel(write, sheet_name="financials")
#
# ...
